# %% [markdown]
# ### Ans 1.

# %%
'''
When creating a custom exception in Python, it's recommended to subclass the built-in Exception class or one of its subclasses.
Here's why it's beneficial to use the Exception class as the base class for custom exceptions:

1.Consistency
2.Error Handling
3.Hierarchy
4.Documentation and Debugging '''
# Out:
# "\nWhen creating a custom exception in Python, it's recommended to subclass the built-in Exception class or one of its subclasses.\nHere's why it's beneficial to use the Exception class as the base class for custom exceptions:\n\n1.Consistency\n2.Error Handling\n3.Hierarchy\n4.Documentation and Debugging "

# %% [markdown]
# ### Ans 2.

# %%
def print_exception_hierarchy(exception_class, indent=0):
    print(' ' * indent + exception_class.__name__)
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass, indent + 4)

print("Python Exception Hierarchy:")
print_exception_hierarchy(BaseException)
# Out:
# Python Exception Hierarchy:
# BaseException
#     Exception
#         TypeError
#             FloatOperation
#             MultipartConversionError
#         StopAsyncIteration
#         StopIteration
#         ImportError
#             ModuleNotFoundError
#             ZipImportError
#         OSError
#             ConnectionError
#                 BrokenPipeError
#                 ConnectionAbortedError
#                 ConnectionRefusedError
#                 ConnectionResetError
#                     RemoteDisconnected
#             BlockingIOError
#             ChildProcessError
#             FileExistsError
#             FileNotFoundError
#             IsADirectoryError
#             NotADirectoryError
#             InterruptedError
#                 InterruptedSystemCall
#             PermissionError
#             ProcessLookupError
#             TimeoutError
#             UnsupportedOperation
#             itimer_error
#             herror
#             gaierror
# ...

# %% [markdown]
# ### Ans 3.

# %%
'''
The ArithmeticError class in Python is a base class for arithmetic-related errors. It serves as the superclass for various arithmetic-related exception classes. 
Some of the errors defined in the ArithmeticError class include:

# 1.OverflowError: Raised when an arithmetic operation exceeds the limits of the numeric type being used. '''

# Syntax

x = 10 ** 1000  # Raises OverflowError due to integer overflow

# 2.ZeroDivisionError: Raised when division or modulo operation is performed with zero as the divisor.

#Syntax

x = 10 / 0  # Raises ZeroDivisionError
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[5], line 15
#       9 x = 10 ** 1000  # Raises OverflowError due to integer overflow
#      11 # 2.ZeroDivisionError: Raised when division or modulo operation is performed with zero as the divisor.
#      12
#      13 #Syntax
# ---> 15 x = 10 / 0  # Raises ZeroDivisionError
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ### Ans 4.

# %%
'''
The LookupError class in Python serves as the base class for errors that occur when a key or index used to access a value in a collection is not found. 
It is a superclass for various lookup-related errors and is useful for catching multiple types of lookup errors in a single except block.

Here are two subclasses of LookupError and explanations with examples:

1.KeyError:KeyError is raised when a dictionary key is not found in a dictionary.

Example: '''

my_dict = {'a': 1, 'b': 2, 'c': 3}
value = my_dict['d']  # Raises KeyError: 'd' not found in dictionary


'''
2.IndexError:IndexError is raised when attempting to access an index that is out of range in a sequence (such as a list, tuple, or string).

Example: '''

my_list = [1, 2, 3]
value = my_list[3]  # Raises IndexError: list index out of range
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 12
#       1 '''
#       2 The LookupError class in Python serves as the base class for errors that occur when a key or index used to access a value in a collection is not found.
#       3 It is a superclass for various lookup-related errors and is useful for catching multiple types of lookup errors in a single except block.
#    (...)
#       8
#       9 Example: '''
#      11 my_dict = {'a': 1, 'b': 2, 'c': 3}
# ---> 12 value = my_dict['d']  # Raises KeyError: 'd' not found in dictionary
#      15 '''
#      16 2.IndexError:IndexError is raised when attempting to access an index that is out of range in a sequence (such as a list, tuple, or string).
#      17
#      18 Example: '''
#      20 my_list = [1, 2, 3]
#
# KeyError: 'd'

# %% [markdown]
# ### Ans 5

# %%
'''
ImportError and ModuleNotFoundError are both exceptions related to importing modules in Python, 
but they have different meanings and are used in different contexts.

ImportError:

ImportError is raised when an import statement fails to import a module or cannot find a module.
This exception can occur due to various reasons, such as:
The module does not exist.
The module's file is not found or cannot be accessed.
The module's file has syntax errors.

Syntax-

try:
    import non_existent_module
except ImportError as e:
    print("ImportError occurred:", e)


2.ModuleNotFoundError:

ModuleNotFoundError is a subclass of ImportError introduced in Python 3.6.
It specifically indicates that the requested module could not be found or imported.
ModuleNotFoundError is raised when Python cannot locate the module specified in the import statement.


Syntax

try:
    import non_existent_module
except ModuleNotFoundError as e:
    print("ModuleNotFoundError occurred:", e)

'''
# Out:
# '\nImportError and ModuleNotFoundError are both exceptions related to importing modules in Python, \nbut they have different meanings and are used in different contexts.\n\nImportError:\n\nImportError is raised when an import statement fails to import a module or cannot find a module.\nThis exception can occur due to various reasons, such as:\nThe module does not exist.\nThe module\'s file is not found or cannot be accessed.\nThe module\'s file has syntax errors.\n\nSyntax-\n\ntry:\n    import non_existent_module\nexcept ImportError as e:\n    print("ImportError occurred:", e)\n\n\n2.ModuleNotFoundError:\n\nModuleNotFoundError is a subclass of ImportError introduced in Python 3.6.\nIt specifically indicates that the requested module could not be found or imported.\nModuleNotFoundError is raised when Python cannot locate the module specified in the import statement.\n\n\nSyntax\n\ntry:\n    import non_existent_module\nexcept ModuleNotFoundError as e:\n    print("ModuleNotFoundError oc
# ...

# %% [markdown]
# ### Ans 6.

# %%
'''
Exception handling is an important aspect of writing robust and reliable Python code. 
Here are some best practices for exception handling in Python:

1.Use specific exception types
2.Handle exceptions gracefully
3.Use try-except blocks judiciously
4.Avoid bare except clauses
5.Consider logging exceptions
6.Test exception handling
